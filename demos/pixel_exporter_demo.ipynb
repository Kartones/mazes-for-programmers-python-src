# %%
# Temporarilly add parent folder to path
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from base.colored_grid import ColoredGrid
from algorithms.binary_tree import BinaryTree
from exporters.pixel_exporter import PixelExporter
from exporters.ascii_exporter import ASCIIExporter

# %%
# Run BinaryTree
grid = ColoredGrid(100, 100)
grid = BinaryTree.on(grid)

# %%
# Color cells
start_cell = grid.cell_at(grid.rows//2, grid.columns//2)
grid.distances = start_cell.distances

# %%
# Export to image
pe = PixelExporter()
pe.render(grid, coloring=True, save=False)
# Out:
# <PIL.Image.Image image mode=RGBA size=402x402 at 0x10F41AE80>
